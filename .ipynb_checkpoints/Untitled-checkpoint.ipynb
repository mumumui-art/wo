# %%
from flask import Flask
import random

app = Flask(__name__)

@app.route('/')
def home():
    return """
    <!DOCTYPE html>
    <html lang="ko">
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>츄르먹기 게임</title>
        <style>
            body {
                display: flex;
                justify-content: center;
                align-items: center;
                height: 100vh;
                margin: 0;
                background-color: #f0f0f0;
                font-family: Arial, sans-serif;
                text-align: center;
                position: relative;
            }
            .container {
                display: flex;
                justify-content: center;
                align-items: center;
                text-align: center;
                flex-direction: column;
            }
            #level, #maxLevel {
                font-size: 24px;
                margin-top: 10px;
            }
            button {
                margin-top: 20px;
                padding: 10px 20px;
                font-size: 18px;
                cursor: pointer;
                border: none;
                border-radius: 5px;
                width: 250px;
            }
            #laserButton {
                background-color: #ff8c00;
                color: white;
            }
            #feedButton {
                background-color: #66cc66;
                color: white;
            }
            .probability {
                font-size: 20px;
                margin-top: 10px;
            }
            #gameInfo {
                margin-top: 10px;
                font-size: 18px;
                display: none;
                text-align: left;
                width: 400px;
                margin-top: 20px;
                position: absolute;
                top: 20px;
                left: 20px;
                background-color: rgba(255, 255, 255, 0.8);
                padding: 20px;
                border-radius: 10px;
                box-shadow: 0px 0px 15px rgba(0, 0, 0, 0.1);
            }
            #showGameInfoButton {
                position: absolute;
                top: 20px;
                left: 20px;
                background-color: #4CAF50;
                color: white;
                font-size: 14px;
                padding: 5px 10px;
                border-radius: 5px;
                cursor: pointer;
                margin-bottom: 10px;
            }
        </style>
    </head>
    <body>
        <button id="showGameInfoButton" onclick="toggleGameInfo()">게임 설명 보기</button>

        <div class="container">
            <div>
                <h1>🐱 고양이에게 츄르 먹이기 🐱</h1>
                <p id="level">츄르 주세요</p>
                <p id="maxLevel" style="font-size: 20px;"></p>
                <button id="feedButton" onclick="feedCat()">츄르 주기</button>
                <button id="laserButton" onclick="playWithLaser()">레이저로 놀아주기 (3)</button>
            </div>
            <div>
                <p class="probability" id="probability"></p>
            </div>
        </div>

        <div id="gameInfo">
            <h3>게임 목표:</h3>
            <p>이 게임의 목표는 귀여운 고양이에게 츄르를 먹여 최대 츄르 개수를 기록하는 것입니다. 고양이는 배가 고플 때만 츄르를 먹습니다. 당신의 역할은 고양이를 배고프게 하여 츄르를 먹게 만드는 것입니다.</p>

            <h3>게임 규칙:</h3>
            <ul>
                <li><strong>츄르 주기:</strong> 버튼을 클릭하면 고양이가 츄르를 먹을 확률이 나타납니다. 성공적으로 츄르를 먹이면 레벨이 올라갑니다.</li>
                <li><strong>레이저로 놀아주기:</strong> 게임 중에 레이저를 사용하면 고양이가 더 쉽게 츄르를 먹을 수 있습니다. 하지만 레이저는 제한된 횟수만 사용 가능합니다.</li>
                <li><strong>확률:</strong> 고양이가 츄르를 먹을 확률은 점점 변동되며, 레벨이 올라갈수록 고양이가 배불러서 츄르를 잘 먹지 않게 됩니다.</li>
                <li><strong>게임 종료:</strong> 고양이가 츄르를 다 먹으면 게임이 종료되며, 당신의 기록을 확인할 수 있습니다.</li>
            </ul>

            <h3>게임 팁:</h3>
            <ul>
                <li>레이저를 사용할 때는 확률을 두 배로 높일 수 있어요. 하지만 레이저는 한정되어 있으니 잘 사용하세요!</li>
                <li>고양이의 레벨이 높아질수록 츄르를 먹을 확률이 낮아지니, 조금 더 전략적으로 플레이해보세요.</li>
            </ul>

            <p><strong>제작자 : 조연우</strong></p>
        </div>

        <script>
            let level = 1;
            let maxLevel = 20;
            let laserCount = 3;
            let maxCatLevel = 1;
            let laserBoostActive = false;
            const probabilities = [
                1.0, 0.9, 0.86, 0.77, 0.68, 0.61, 0.60, 0.58, 0.57, 0.51,
                0.45, 0.35, 0.4, 0.32, 0.30, 0.3, 0.3, 0.3, 0.9, 0.2
            ];

            function feedCat() {
                if (level <= maxLevel) {
                    let rand = Math.random();
                    if (laserBoostActive) {
                        if (rand <= probabilities[level - 1] * 2) {
                            level++;
                            maxCatLevel = Math.max(maxCatLevel, level);
                            updateLevelDisplay();
                            laserBoostActive = false;
                        } else {
                            resetGame();
                        }
                    } else {
                        if (rand <= probabilities[level - 1]) {
                            level++;
                            maxCatLevel = Math.max(maxCatLevel, level);
                            updateLevelDisplay();
                        } else {
                            resetGame();
                        }
                    }
                } else {
                    document.getElementById("level").innerText = "🎉 츄르 다 먹었어요! 🎉";
                }
                updateLaserButton();
                updateProbability();
            }

            function playWithLaser() {
                if (laserCount > 0) {
                    laserCount--;
                    let rand = Math.random();
                    if (rand <= 0.5) {
                        laserBoostActive = true;
                        alert("레이저 놀이!! 고양이가 배고파서 츄르를 무조건 먹을거 같아요");
                    } else {
                        alert("레이저로 놀아주었지만, 배불러서 움직이지를 않네요");
                    }
                    updateLaserButton();
                } else {
                    alert("레이저를 더 이상 사용할 수 없습니다!");
                }
            }

            function updateLaserButton() {
                const laserButton = document.getElementById("laserButton");
                if (laserCount > 0) {
                    laserButton.innerText = "레이저로 놀아주기 (" + laserCount + ")";
                } else {
                    laserButton.disabled = true;
                    laserButton.innerText = "레이저로 놀아주기 종료";
                }
            }

            function updateLevelDisplay() {
                document.getElementById("level").innerText = "츄르 " + level + "개 냠";
                document.getElementById("maxLevel").innerText = "최대 츄르 개수: " + maxCatLevel;
            }

            function updateProbability() {
                const probabilityText = probabilities[level - 1] * 100;
                document.getElementById("probability").innerText = `츄르 먹을 확률: ${probabilityText.toFixed(2)}%`;
            }

            function toggleGameInfo() {
                const gameInfo = document.getElementById("gameInfo");
                gameInfo.style.display = gameInfo.style.display === "none" ? "block" : "none";
            }

            function resetGame() {
                level = 1;
                maxCatLevel = 1;
                updateLevelDisplay();
                alert("게임 종료! 다시 시작합니다.");
            }

            updateLaserButton();
            updateProbability();
        </script>
    </body>
    </html>
    """

if __name__ == '__main__':
    app.run(debug=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "25d001ad-d777-4df6-aea1-33fb7949b775",
#       7    "metadata": {},
#       8    "outputs": [
#       9     {
#      10      "name": "stdout",
#      11      "output_type": "stream",
#      12      "text": [
#      13       " * Serving Flask app '__main__'\n",
#      14       " * Debug mode: off\n"
#      15      ]
#      16     },
#      17     {
#      18      "name": "stderr",
#      19      "output_type": "stream",
#      20      "text": [
#      21       "WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.\n",
#      22       " * Running on http://127.0.0.1:5000\n",
#      23       "Press CTRL+C to quit\n",
#      24       "127.0.0.1 - - [28/Feb/2025 15:52:57] \"GET / HTTP/1.1\" 200 -\n"
#      25      ]
#      26     }
#      27    ],
#      28    "source": [
#      29     "from flask import Flask\n",
#      30     "import random  # 랜덤 숫자를 생성할 수 있도록 임포트\n",
#      31     "\n",
#      32     "app = Flask(__name__)\n",
#      33     "\n",
#      34     "@app.route('/')\n",
#      35     "def home():\n",
#      36     "    return \"\"\"\n",
#      37     "    <!DOCTYPE html>\n",
#      38     "    <html lang=\"ko\">\n",
#      39     "    <head>\n",
#      40     "        <meta charset=\"UTF-8\">\n",
#      41     "        <meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0\">\n",
#      42     "        <title>츄르먹기 게임</title>\n",
#      43     "        <style>\n",
#      44     "            body {\n",
#      45     "                display: flex;\n",
#      46     "                justify-content: center;\n",
#      47     "                align-items: center;\n",
#      48     "                height: 100vh;\n",
#      49     "                margin: 0;\n",
#      50     "                background-color: #f0f0f0;\n",
#      51     "                font-family: Arial, sans-serif;\n",
#      52     "                text-align: center;\n",
#      53     "                position: relative;\n",
#      54     "            }\n",
#      55     "            .container {\n",
#      56     "                display: flex;\n",
#      57     "                justify-content: center;\n",
#      58     "                align-items: center;\n",
#      59     "                text-align: center;\n",
#      60     "                flex-direction: column;\n",
#      61     "            }\n",
#      62     "            #level, #maxLevel {\n",
#      63     "                font-size: 24px;\n",
#      64     "                margin-top: 10px;\n",
#      65     "            }\n",
#      66     "            button {\n",
#      67     "                margin-top: 20px;\n",
#      68     "                padding: 10px 20px;\n",
#      69     "                font-size: 18px;\n",
#      70     "                cursor: pointer;\n",
#      71     "                border: none;\n",
#      72     "                border-radius: 5px;\n",
#      73     "                width: 250px;\n",
#      74     "            }\n",
#      75     "            #laserButton {\n",
#      76     "                background-color: #ff8c00;\n",
#      77     "                color: white;\n",
#      78     "            }\n",
#      79     "            #feedButton {\n",
#      80     "                background-color: #66cc66;\n",
#      81     "                color: white;\n",
#      82     "            }\n",
#      83     "            .probability {\n",
#      84     "                font-size: 20px;\n",
#      85     "                margin-top: 10px;\n",
#      86     "            }\n",
#      87     "            #gameInfo {\n",
#      88     "                margin-top: 10px;\n",
#      89     "                font-size: 18px;\n",
#      90     "                display: none;\n",
#      91     "                text-align: left;\n",
#      92     "                width: 400px;\n",
#      93     "                margin-top: 20px;\n",
#      94     "                position: absolute;\n",
#      95     "                top: 20px;\n",
#      96     "                left: 20px;  /* 왼쪽 끝에 위치하도록 설정 */\n",
#      97     "                background-color: rgba(255, 255, 255, 0.8);\n",
#      98     "                padding: 20px;\n",
#      99     "                border-radius: 10px;\n",
#     100     "                box-shadow: 0px 0px 15px rgba(0, 0, 0, 0.1);\n",
#     101     "            }\n",
#     102     "            #showGameInfoButton {\n",
#     103     "                position: absolute;\n",
#     104     "                top: 20px;\n",
#     105     "                left: 20px;\n",
#     106     "                background-color: #4CAF50;\n",
#     107     "                color: white;\n",
#     108     "                font-size: 14px;\n",
#     109     "                padding: 5px 10px;\n",
#     110     "                border-radius: 5px;\n",
#     111     "                cursor: pointer;\n",
#     112     "                margin-bottom: 10px;\n",
#     113     "            }\n",
#     114     "        </style>\n",
#     115     "    </head>\n",
#     116     "    <body>\n",
#     117     "        <button id=\"showGameInfoButton\" onclick=\"toggleGameInfo()\">게임 설명 보기</button>\n",
#     118     "\n",
#     119     "        <div class=\"container\">\n",
#     120     "            <div>\n",
#     121     "                <h1>🐱 고양이에게 츄르 먹이기 🐱</h1>\n",
#     122     "                <p id=\"level\">츄르 주세요</p>\n",
#     123     "                <p id=\"maxLevel\" style=\"font-size: 20px;\"></p>\n",
#     124     "                <button id=\"feedButton\" onclick=\"feedCat()\">츄르 주기</button>\n",
#     125     "                <button id=\"laserButton\" onclick=\"playWithLaser()\">레이저로 놀아주기 (3)</button>\n",
#     126     "            </div>\n",
#     127     "            <div>\n",
#     128     "                <p class=\"probability\" id=\"probability\"></p>\n",
#     129     "            </div>\n",
#     130     "        </div>\n",
#     131     "\n",
#     132     "        <div id=\"gameInfo\">\n",
#     133     "            <h3>게임 목표:</h3>\n",
#     134     "            <p>이 게임의 목표는 귀여운 고양이에게 츄르를 먹여 최대 츄르 개수를 기록하는 것입니다. 고양이는 배가 고플 때만 츄르를 먹습니다. 당신의 역할은 고양이를 배고프게 하여 츄르를 먹게 만드는 것입니다.</p>\n",
#     135     "\n",
#     136     "            <h3>게임 규칙:</h3>\n",
#     137     "            <ul>\n",
#     138     "                <li><strong>츄르 주기:</strong> 버튼을 클릭하면 고양이가 츄르를 먹을 확률이 나타납니다. 성공적으로 츄르를 먹이면 레벨이 올라갑니다.</li>\n",
#     139     "                <li><strong>레이저로 놀아주기:</strong> 게임 중에 레이저를 사용하면 고양이가 더 쉽게 츄르를 먹을 수 있습니다. 하지만 레이저는 제한된 횟수만 사용 가능합니다.</li>\n",
#     140     "                <li><strong>확률:</strong> 고양이가 츄르를 먹을 확률은 점점 변동되며, 레벨이 올라갈수록 고양이가 배불러서 츄르를 잘 먹지 않게 됩니다.</li>\n",
#     141     "                <li><strong>게임 종료:</strong> 고양이가 츄르를 다 먹으면 게임이 종료되며, 당신의 기록을 확인할 수 있습니다.</li>\n",
#     142     "            </ul>\n",
#     143     "\n",
#     144     "            <h3>게임 팁:</h3>\n",
#     145     "            <ul>\n",
#     146     "                <li>레이저를 사용할 때는 확률을 두 배로 높일 수 있어요. 하지만 레이저는 한정되어 있으니 잘 사용하세요!</li>\n",
#     147     "                <li>고양이의 레벨이 높아질수록 츄르를 먹을 확률이 낮아지니, 조금 더 전략적으로 플레이해보세요.</li>\n",
#     148     "            </ul>\n",
#     149     "\n",
#     150     "            <p><strong>제작자 : 조연우</strong></p>\n",
#     151     "        </div>\n",
#     152     "\n",
#     153     "        <script>\n",
#     154     "            let level = 1;\n",
#     155     "            let maxLevel = 20;\n",
#     156     "            let laserCount = 3;\n",
#     157     "            let maxCatLevel = 1;\n",
#     158     "            let laserBoostActive = false;\n",
#     159     "            const probabilities = [\n",
#     160     "                1.0, 0.9, 0.86, 0.77, 0.68, 0.61, 0.60, 0.58, 0.57, 0.51,\n",
#     161     "                0.45, 0.35, 0.4, 0.32, 0.30, 0.3, 0.3, 0.3, 0.9, 0.2\n",
#     162     "            ];\n",
#     163     "\n",
#     164     "            function feedCat() {\n",
#     165     "                if (level <= maxLevel) {\n",
#     166     "                    let rand = Math.random();\n",
#     167     "                    if (laserBoostActive) {\n",
#     168     "                        if (rand <= probabilities[level - 1] * 2) {\n",
#     169     "                            level++;\n",
#     170     "                            maxCatLevel = Math.max(maxCatLevel, level);\n",
#     171     "                            updateLevelDisplay();\n",
#     172     "                            laserBoostActive = false;\n",
#     173     "                        } else {\n",
#     174     "                            resetGame();\n",
#     175     "                        }\n",
#     176     "                    } else {\n",
#     177     "                        if (rand <= probabilities[level - 1]) {\n",
#     178     "                            level++;\n",
#     179     "                            maxCatLevel = Math.max(maxCatLevel, level);\n",
#     180     "                            updateLevelDisplay();\n",
#     181     "                        } else {\n",
#     182     "                            resetGame();\n",
#     183     "                        }\n",
#     184     "                    }\n",
#     185     "                } else {\n",
#     186     "                    document.getElementById(\"level\").innerText = \"🎉 츄르 다 먹었어요! 🎉\";\n",
#     187     "                }\n",
#     188     "                updateLaserButton();\n",
#     189     "                updateProbability();\n",
#     190     "            }\n",
#     191     "\n",
#     192     "            function playWithLaser() {\n",
#     193     "                if (laserCount > 0) {\n",
#     194     "                    laserCount--;\n",
#     195     "                    let rand = Math.random();\n",
#     196     "                    if (rand <= 0.5) {\n",
#     197     "                        laserBoostActive = true;\n",
#     198     "                        alert(\"레이저 놀이!! 고양이가 배고파서 츄르를 무조건 먹을거 같아요\");\n",
#     199     "                    } else {\n",
#     200     "                        alert(\"레이저로 놀아주었지만, 배불러서 움직이지를 않네요\");\n",
#     201     "                    }\n",
#     202     "                    updateLaserButton();\n",
#     203     "                } else {\n",
#     204     "                    alert(\"레이저를 더 이상 사용할 수 없습니다!\");\n",
#     205     "                }\n",
#     206     "            }\n",
#     207     "\n",
#     208     "            function updateLaserButton() {\n",
#     209     "                const laserButton = document.getElementById(\"laserButton\");\n",
#     210     "                if (laserCount > 0) {\n",
#     211     "                    laserButton.innerText = \"레이저로 놀아주기 (\" + laserCount + \")\";\n",
#     212     "                } else {\n",
#     213     "                    laserButton.disabled = true;\n",
#     214     "                    laserButton.innerText = \"레이저로 놀아주기 종료\";\n",
#     215     "                }\n",
#     216     "            }\n",
#     217     "\n",
#     218     "            function updateLevelDisplay() {\n",
#     219     "                document.getElementById(\"level\").innerText = \"츄르 \" + level + \"개 냠\";\n",
#     220     "                document.getElementById(\"maxLevel\").innerText = \"최대 츄르 개수: \" + maxCatLevel;\n",
#     221     "            }\n",
#     222     "\n",
#     223     "            function updateProbability() {\n",
#     224     "                const probabilityText = probabilities[level - 1];\n",
#     225     "                document.getElementById(\"probability\").innerText = `현재 확률: ${Math.round(probabilityText * 100)}%`;\n",
#     226     "            }\n",
#     227     "\n",
#     228     "            function resetGame() {\n",
#     229     "                level = 1;\n",
#     230     "                document.getElementById(\"level\").innerText = \"배불러서 낮잠자러 갔어요...\";\n",
#     231     "                document.getElementById(\"maxLevel\").innerText = \"최대 츄르 개수: \" + maxCatLevel;\n",
#     232     "                laserBoostActive = false;\n",
#     233     "                laserCount = 3;\n",
#     234     "                updateLaserButton();\n",
#     235     "                updateProbability();\n",
#     236     "            }\n",
#     237     "\n",
#     238     "            function toggleGameInfo() {\n",
#     239     "                const gameInfo = document.getElementById(\"gameInfo\");\n",
#     240     "                const showGameInfoButton = document.getElementById(\"showGameInfoButton\");\n",
#     241     "                \n",
#     242     "                if (gameInfo.style.display === \"none\") {\n",
#     243     "                    gameInfo.style.display = \"block\";\n",
#     244     "                    showGameInfoButton.innerText = \"설명을 그만 보려면 다시 클릭하세요\";\n",
#     245     "                } else {\n",
#     246     "                    gameInfo.style.display = \"none\";\n",
#     247     "                    showGameInfoButton.innerText = \"게임 설명 보기\";\n",
#     248     "                }\n",
#     249     "            }\n",
#     250     "        </script>\n",
#     251     "    </body>\n",
#     252     "    </html>\n",
#     253     "    \"\"\"\n",
#     254     "\n",
#     255     "if __name__ == '__main__':\n",
#     256     "    app.run(debug=False)\n"
#     257    ]
#     258   },
#     259   {
#     260    "cell_type": "code",
#     261    "execution_count": null,
#     262    "id": "f9398b5d-68a0-4c64-bd3b-0a898cf86cc5",
#     263    "metadata": {},
#     264    "outputs": [],
#     265    "source": []
#     266   },
#     267   {
#     268    "cell_type": "code",
#     269    "execution_count": null,
#     270    "id": "17467441-0233-4618-af6d-5c18a6529ede",
#     271    "metadata": {},
#     272    "outputs": [],
#     273    "source": []
#     274   },
#     275   {
#     276    "cell_type": "code",
#     277    "execution_count": null,
#     278    "id": "4f9683cd-fb8a-47ff-94f4-3bbb86a20da1",
#     279    "metadata": {},
#     280    "outputs": [],
#     281    "source": []
#     282   }
#     283  ],
#     284  "metadata": {
#     285   "kernelspec": {
#     286    "display_name": "Python [conda env:base] *",
#     287    "language": "python",
#     288    "name": "conda-base-py"
#     289   },
#     290   "language_info": {
#     291    "codemirror_mode": {
#     292     "name": "ipython",
#     293     "version": 3
#     294    },
#     295    "file_extension": ".py",
#     296    "mimetype": "text/x-python",
#     297    "name": "python",
#     298    "nbconvert_exporter": "python",
#     299    "pygments_lexer": "ipython3",
#     300    "version": "3.12.7"
#     301   }
#     302  },
#     303  "nbformat": 4,
#     304  "nbformat_minor": 5
#     305 }
#
# NameError: name 'null' is not defined
